# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import os

def scrape_f1_standings(year):
    url = f"https://www.formula1.com/en/results.html/{year}/drivers.html"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', class_='resultsarchive-table')
    
    data = []
    if table:
        for row in table.find_all('tr')[1:]:  # Skip the header row
            cols = row.find_all('td')
            if len(cols) > 0:
                position = cols[1].text.strip()
                driver = cols[2].text.strip()
                nationality = cols[3].text.strip()
                car = cols[4].text.strip()
                points = cols[5].text.strip()
                data.append([position, driver, nationality, car, points])
    
    return data

# Create a directory to store the CSV files
if not os.path.exists('f1_standings'):
    os.makedirs('f1_standings')

# Scrape data for years from 1950 to 2023 (inclusive)
for year in range(1950, 2024):  # Changed this line to include 2023
    print(f"Scraping data for {year}...")
    year_data = scrape_f1_standings(year)
    
    if year_data:
        # Create a DataFrame for the year
        df = pd.DataFrame(year_data, columns=['Position', 'Driver', 'Nationality', 'Car', 'Points'])
        
        # Split the 'Driver' column
        df[['First Name', 'Last Name', 'Code']] = df['Driver'].str.split('\n', expand=True)
        
        # Combine 'First Name' and 'Last Name' into 'Full Name'
        df['Full Name'] = df['First Name'] + ' ' + df['Last Name']
        
        # Rearrange the columns
        columns_order = ['Position', 'Full Name', 'Nationality', 'Car', 'Points']
        df = df[columns_order]
        
        # Save to a CSV file
        filename = f'f1_standings/f1_driver_standings_{year}.csv'
        df.to_csv(filename, index=False)
        print(f"Saved data for {year} to {filename}")
    else:
        print(f"No data found for {year}")
    
    # Add a delay to avoid overwhelming the server
    time.sleep(1)

print("Scraping complete!")
# Out:
# Scraping data for 1950...
# Saved data for 1950 to f1_standings/f1_driver_standings_1950.csv
# Scraping data for 1951...
# Saved data for 1951 to f1_standings/f1_driver_standings_1951.csv
# Scraping data for 1952...
# Saved data for 1952 to f1_standings/f1_driver_standings_1952.csv
# Scraping data for 1953...
# Saved data for 1953 to f1_standings/f1_driver_standings_1953.csv
# Scraping data for 1954...
# Saved data for 1954 to f1_standings/f1_driver_standings_1954.csv
# Scraping data for 1955...
# Saved data for 1955 to f1_standings/f1_driver_standings_1955.csv
# Scraping data for 1956...
# Saved data for 1956 to f1_standings/f1_driver_standings_1956.csv
# Scraping data for 1957...
# Saved data for 1957 to f1_standings/f1_driver_standings_1957.csv
# Scraping data for 1958...
# Saved data for 1958 to f1_standings/f1_driver_standings_1958.csv
# Scraping data for 1959...
# Saved data for 1959 to f1_standings/f1_driver_standings_1959.csv
# Scraping data for 1960...
# Saved data for 1960 to f1_standings/f1_driver_standings_1960.csv
# Scraping data for 1961...
# Saved data for 1961 to f1_standings/f1_driver_standings_1961.csv
# Scraping data for 1962...
# Saved data for 1962 to f1_standings/f1_driver_standings_1962.csv
# Scraping data for 1963...
# Saved data for 1963 to f1_standings/f1_driver_standings_1963.csv
# Scraping data for 1964...
# Saved data for 1964 to f1_standings/f1_driver_standings_1964.csv
# Scraping data for 1965...
# Saved data for 1965 to f1_standings/f1_driver_standings_1965.csv
# Scraping data for 1966...
# Saved data for 1966 to f1_standings/f1_driver_standings_1966.csv
# Scraping data for 1967...
# Saved data for 1967 to f1_standings/f1_driver_standings_1967.csv
# Scraping data for 1968...
# Saved data for 1968 to f1_standings/f1_driver_standings_1968.csv
# Scraping data for 1969...
# Saved data for 1969 to f1_standings/f1_driver_standings_1969.csv
# Scraping data for 1970...
# Saved data for 1970 to f1_standings/f1_driver_standings_1970.csv
# Scraping data for 1971...
# Saved data for 1971 to f1_standings/f1_driver_standings_1971.csv
# Scraping data for 1972...
# Saved data for 1972 to f1_standings/f1_driver_standings_1972.csv
# Scraping data for 1973...
# Saved data for 1973 to f1_standings/f1_driver_standings_1973.csv
# Scraping data for 1974...
# Saved data for 1974 to f1_standings/f1_driver_standings_1974.csv
# Scraping data for 1975...
# Saved data for 1975 to f1_standings/f1_driver_standings_1975.csv
# Scraping data for 1976...
# Saved data for 1976 to f1_standings/f1_driver_standings_1976.csv
# Scraping data for 1977...
# Saved data for 1977 to f1_standings/f1_driver_standings_1977.csv
# Scraping data for 1978...
# Saved data for 1978 to f1_standings/f1_driver_standings_1978.csv
# Scraping data for 1979...
# Saved data for 1979 to f1_standings/f1_driver_standings_1979.csv
# Scraping data for 1980...
# Saved data for 1980 to f1_standings/f1_driver_standings_1980.csv
# Scraping data for 1981...
# Saved data for 1981 to f1_standings/f1_driver_standings_1981.csv
# Scraping data for 1982...
# Saved data for 1982 to f1_standings/f1_driver_standings_1982.csv
# Scraping data for 1983...
# Saved data for 1983 to f1_standings/f1_driver_standings_1983.csv
# Scraping data for 1984...
# Saved data for 1984 to f1_standings/f1_driver_standings_1984.csv
# Scraping data for 1985...
# Saved data for 1985 to f1_standings/f1_driver_standings_1985.csv
# Scraping data for 1986...
# Saved data for 1986 to f1_standings/f1_driver_standings_1986.csv
# Scraping data for 1987...
# Saved data for 1987 to f1_standings/f1_driver_standings_1987.csv
# Scraping data for 1988...
# Saved data for 1988 to f1_standings/f1_driver_standings_1988.csv
# Scraping data for 1989...
# Saved data for 1989 to f1_standings/f1_driver_standings_1989.csv
# Scraping data for 1990...
# Saved data for 1990 to f1_standings/f1_driver_standings_1990.csv
# Scraping data for 1991...
# Saved data for 1991 to f1_standings/f1_driver_standings_1991.csv
# Scraping data for 1992...
# Saved data for 1992 to f1_standings/f1_driver_standings_1992.csv
# Scraping data for 1993...
# Saved data for 1993 to f1_standings/f1_driver_standings_1993.csv
# Scraping data for 1994...
# Saved data for 1994 to f1_standings/f1_driver_standings_1994.csv
# Scraping data for 1995...
# Saved data for 1995 to f1_standings/f1_driver_standings_1995.csv
# Scraping data for 1996...
# Saved data for 1996 to f1_standings/f1_driver_standings_1996.csv
# Scraping data for 1997...
# Saved data for 1997 to f1_standings/f1_driver_standings_1997.csv
# Scraping data for 1998...
# Saved data for 1998 to f1_standings/f1_driver_standings_1998.csv
# Scraping data for 1999...
# Saved data for 1999 to f1_standings/f1_driver_standings_1999.csv
# Scraping data for 2000...
# Saved data for 2000 to f1_standings/f1_driver_standings_2000.csv
# Scraping data for 2001...
# Saved data for 2001 to f1_standings/f1_driver_standings_2001.csv
# Scraping data for 2002...
# Saved data for 2002 to f1_standings/f1_driver_standings_2002.csv
# Scraping data for 2003...
# Saved data for 2003 to f1_standings/f1_driver_standings_2003.csv
# Scraping data for 2004...
# Saved data for 2004 to f1_standings/f1_driver_standings_2004.csv
# Scraping data for 2005...
# Saved data for 2005 to f1_standings/f1_driver_standings_2005.csv
# Scraping data for 2006...
# Saved data for 2006 to f1_standings/f1_driver_standings_2006.csv
# Scraping data for 2007...
# Saved data for 2007 to f1_standings/f1_driver_standings_2007.csv
# Scraping data for 2008...
# Saved data for 2008 to f1_standings/f1_driver_standings_2008.csv
# Scraping data for 2009...
# Saved data for 2009 to f1_standings/f1_driver_standings_2009.csv
# Scraping data for 2010...
# Saved data for 2010 to f1_standings/f1_driver_standings_2010.csv
# Scraping data for 2011...
# Saved data for 2011 to f1_standings/f1_driver_standings_2011.csv
# Scraping data for 2012...
# Saved data for 2012 to f1_standings/f1_driver_standings_2012.csv
# Scraping data for 2013...
# Saved data for 2013 to f1_standings/f1_driver_standings_2013.csv
# Scraping data for 2014...
# Saved data for 2014 to f1_standings/f1_driver_standings_2014.csv
# Scraping data for 2015...
# Saved data for 2015 to f1_standings/f1_driver_standings_2015.csv
# Scraping data for 2016...
# Saved data for 2016 to f1_standings/f1_driver_standings_2016.csv
# Scraping data for 2017...
# Saved data for 2017 to f1_standings/f1_driver_standings_2017.csv
# Scraping data for 2018...
# Saved data for 2018 to f1_standings/f1_driver_standings_2018.csv
# Scraping data for 2019...
# Saved data for 2019 to f1_standings/f1_driver_standings_2019.csv
# Scraping data for 2020...
# Saved data for 2020 to f1_standings/f1_driver_standings_2020.csv
# Scraping data for 2021...
# Saved data for 2021 to f1_standings/f1_driver_standings_2021.csv
# Scraping data for 2022...
# Saved data for 2022 to f1_standings/f1_driver_standings_2022.csv
# Scraping data for 2023...
# Saved data for 2023 to f1_standings/f1_driver_standings_2023.csv
# Scraping complete!
