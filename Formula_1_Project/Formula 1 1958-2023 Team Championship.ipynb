# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

def get_available_years():
    url = "https://www.formula1.com/en/results.html/2023/team.html"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    year_options = soup.select('select.resultsarchive-filter-form-select option')
    years = [int(option['value']) for option in year_options if option['value'].isdigit()]
    return sorted(years, reverse=True)

def scrape_f1_team_standings(year):
    url = f"https://www.formula1.com/en/results.html/{year}/team.html"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    table = soup.find('table', class_='resultsarchive-table')
    if not table:
        print(f"No data found for {year}")
        return None
    
    rows = table.find_all('tr')[1:]  # Skip the header row
    data = []
    
    for row in rows:
        cols = row.find_all('td')
        if len(cols) >= 4:  # Ensure we have at least 4 columns
            position = cols[1].text.strip()
            team = cols[2].text.strip()
            points = cols[3].text.strip()  # Points should be in the 4th column
            data.append([position, team, points])
    
    return data

# Create a directory to store CSV files
if not os.path.exists('f1_team_standings'):
    os.makedirs('f1_team_standings')

# Get all available years
available_years = get_available_years()

for year in available_years:
    print(f"Scraping data for {year}...")
    year_data = scrape_f1_team_standings(year)
    
    if year_data:
        df = pd.DataFrame(year_data, columns=['POS', 'TEAM', 'PTS'])
        
        # Save to CSV
        csv_filename = f'f1_team_standings/f1_team_standings_{year}.csv'
        df.to_csv(csv_filename, index=False)
        print(f"Data for {year} saved to {csv_filename}")
        
        # Display the first few rows of the data
        print(df.head())
        print("\n")
    else:
        print(f"No data available for {year}\n")

print("Scraping complete. CSV files have been saved in the 'f1_standings' directory.")
# Out:
# Scraping data for 2024...
# Data for 2024 saved to f1_team_standings/f1_team_standings_2024.csv
#   POS                          TEAM  PTS
# 0   1    Red Bull Racing Honda RBPT  339
# 1   2                       Ferrari  276
# 2   3              McLaren Mercedes  250
# 3   4                      Mercedes  159
# 4   5  Aston Martin Aramco Mercedes   58
#
#
# Scraping data for 2023...
# Data for 2023 saved to f1_team_standings/f1_team_standings_2023.csv
#   POS                          TEAM  PTS
# 0   1    Red Bull Racing Honda RBPT  860
# 1   2                      Mercedes  409
# 2   3                       Ferrari  406
# 3   4              McLaren Mercedes  302
# 4   5  Aston Martin Aramco Mercedes  280
#
#
# Scraping data for 2022...
# Data for 2022 saved to f1_team_standings/f1_team_standings_2022.csv
#   POS                  TEAM  PTS
# 0   1  Red Bull Racing RBPT  759
# 1   2               Ferrari  554
# 2   3              Mercedes  515
# 3   4        Alpine Renault  173
# 4   5      McLaren Mercedes  159
#
#
# Scraping data for 2021...
# Data for 2021 saved to f1_team_standings/f1_team_standings_2021.csv
#   POS                   TEAM    PTS
# 0   1               Mercedes  613.5
# 1   2  Red Bull Racing Honda  585.5
# 2   3                Ferrari  323.5
# 3   4       McLaren Mercedes    275
# 4   5         Alpine Renault    155
#
#
# Scraping data for 2020...
# Data for 2020 saved to f1_team_standings/f1_team_standings_2020.csv
#   POS                       TEAM  PTS
# 0   1                   Mercedes  573
# 1   2      Red Bull Racing Honda  319
# 2   3            McLaren Renault  202
# 3   4  Racing Point BWT Mercedes  195
# 4   5                    Renault  181
#
#
# Scraping data for 2019...
# Data for 2019 saved to f1_team_standings/f1_team_standings_2019.csv
#   POS                   TEAM  PTS
# 0   1               Mercedes  739
# 1   2                Ferrari  504
# 2   3  Red Bull Racing Honda  417
# 3   4        McLaren Renault  145
# 4   5                Renault   91
#
#
# Scraping data for 2018...
# Data for 2018 saved to f1_team_standings/f1_team_standings_2018.csv
#   POS                       TEAM  PTS
# 0   1                   Mercedes  655
# 1   2                    Ferrari  571
# 2   3  Red Bull Racing TAG Heuer  419
# 3   4                    Renault  122
# 4   5               Haas Ferrari   93
#
#
# Scraping data for 2017...
# Data for 2017 saved to f1_team_standings/f1_team_standings_2017.csv
#   POS                       TEAM  PTS
# 0   1                   Mercedes  668
# 1   2                    Ferrari  522
# 2   3  Red Bull Racing TAG Heuer  368
# 3   4       Force India Mercedes  187
# 4   5          Williams Mercedes   83
#
#
# Scraping data for 2016...
# Data for 2016 saved to f1_team_standings/f1_team_standings_2016.csv
#   POS                       TEAM  PTS
# 0   1                   Mercedes  765
# 1   2  Red Bull Racing TAG Heuer  468
# 2   3                    Ferrari  398
# 3   4       Force India Mercedes  173
# 4   5          Williams Mercedes  138
#
#
# Scraping data for 2015...
# Data for 2015 saved to f1_team_standings/f1_team_standings_2015.csv
#   POS                     TEAM  PTS
# 0   1                 Mercedes  703
# 1   2                  Ferrari  428
# 2   3        Williams Mercedes  257
# 3   4  Red Bull Racing Renault  187
# 4   5     Force India Mercedes  136
#
#
# Scraping data for 2014...
# Data for 2014 saved to f1_team_standings/f1_team_standings_2014.csv
#   POS                     TEAM  PTS
# 0   1                 Mercedes  701
# 1   2  Red Bull Racing Renault  405
# 2   3        Williams Mercedes  320
# 3   4                  Ferrari  216
# 4   5         McLaren Mercedes  181
#
#
# Scraping data for 2013...
# Data for 2013 saved to f1_team_standings/f1_team_standings_2013.csv
#   POS                     TEAM  PTS
# 0   1  Red Bull Racing Renault  596
# 1   2                 Mercedes  360
# 2   3                  Ferrari  354
# 3   4            Lotus Renault  315
# 4   5         McLaren Mercedes  122
#
#
# Scraping data for 2012...
# Data for 2012 saved to f1_team_standings/f1_team_standings_2012.csv
#   POS                     TEAM  PTS
# 0   1  Red Bull Racing Renault  460
# 1   2                  Ferrari  400
# 2   3         McLaren Mercedes  378
# 3   4            Lotus Renault  303
# 4   5                 Mercedes  142
#
#
# Scraping data for 2011...
# Data for 2011 saved to f1_team_standings/f1_team_standings_2011.csv
#   POS                     TEAM  PTS
# 0   1  Red Bull Racing Renault  650
# 1   2         McLaren Mercedes  497
# 2   3                  Ferrari  375
# 3   4                 Mercedes  165
# 4   5                  Renault   73
#
#
# Scraping data for 2010...
# Data for 2010 saved to f1_team_standings/f1_team_standings_2010.csv
#   POS              TEAM  PTS
# 0   1       RBR Renault  498
# 1   2  McLaren Mercedes  454
# 2   3           Ferrari  396
# 3   4          Mercedes  214
# 4   5           Renault  163
#
#
# Scraping data for 2009...
# Data for 2009 saved to f1_team_standings/f1_team_standings_2009.csv
#   POS              TEAM    PTS
# 0   1    Brawn Mercedes    172
# 1   2       RBR Renault  153.5
# 2   3  McLaren Mercedes     71
# 3   4           Ferrari     70
# 4   5            Toyota   59.5
#
#
# Scraping data for 2008...
# Data for 2008 saved to f1_team_standings/f1_team_standings_2008.csv
#   POS              TEAM  PTS
# 0   1           Ferrari  172
# 1   2  McLaren Mercedes  151
# 2   3        Sauber BMW  135
# 3   4           Renault   80
# 4   5            Toyota   56
#
#
# Scraping data for 2007...
# Data for 2007 saved to f1_team_standings/f1_team_standings_2007.csv
#   POS              TEAM  PTS
# 0   1           Ferrari  204
# 1   2        Sauber BMW  101
# 2   3           Renault   51
# 3   4   Williams Toyota   33
# 4   5  Red Bull Renault   24
#
#
# Scraping data for 2006...
# Data for 2006 saved to f1_team_standings/f1_team_standings_2006.csv
#   POS              TEAM  PTS
# 0   1           Renault  206
# 1   2           Ferrari  201
# 2   3  McLaren Mercedes  110
# 3   4             Honda   86
# 4   5        Sauber BMW   36
#
#
# Scraping data for 2005...
# Data for 2005 saved to f1_team_standings/f1_team_standings_2005.csv
#   POS              TEAM  PTS
# 0   1           Renault  191
# 1   2  McLaren Mercedes  182
# 2   3           Ferrari  100
# 3   4            Toyota   88
# 4   5      Williams BMW   66
#
#
# Scraping data for 2004...
# Data for 2004 saved to f1_team_standings/f1_team_standings_2004.csv
#   POS              TEAM  PTS
# 0   1           Ferrari  262
# 1   2         BAR Honda  119
# 2   3           Renault  105
# 3   4      Williams BMW   88
# 4   5  McLaren Mercedes   69
#
#
# Scraping data for 2003...
# Data for 2003 saved to f1_team_standings/f1_team_standings_2003.csv
#   POS              TEAM  PTS
# 0   1           Ferrari  158
# 1   2      Williams BMW  144
# 2   3  McLaren Mercedes  142
# 3   4           Renault   88
# 4   5         BAR Honda   26
#
#
# Scraping data for 2002...
# Data for 2002 saved to f1_team_standings/f1_team_standings_2002.csv
#   POS              TEAM  PTS
# 0   1           Ferrari  221
# 1   2      Williams BMW   92
# 2   3  McLaren Mercedes   65
# 3   4           Renault   23
# 4   5   Sauber Petronas   11
#
#
# Scraping data for 2001...
# Data for 2001 saved to f1_team_standings/f1_team_standings_2001.csv
#   POS              TEAM  PTS
# 0   1           Ferrari  179
# 1   2  McLaren Mercedes  102
# 2   3      Williams BMW   80
# 3   4   Sauber Petronas   21
# 4   5      Jordan Honda   19
#
#
# Scraping data for 2000...
# Data for 2000 saved to f1_team_standings/f1_team_standings_2000.csv
#   POS               TEAM  PTS
# 0   1            Ferrari  170
# 1   2   McLaren Mercedes  152
# 2   3       Williams BMW   36
# 3   4  Benetton Playlife   20
# 4   5          BAR Honda   20
#
#
# Scraping data for 1999...
# Data for 1999 saved to f1_team_standings/f1_team_standings_1999.csv
#   POS                TEAM  PTS
# 0   1             Ferrari  128
# 1   2    McLaren Mercedes  124
# 2   3  Jordan Mugen Honda   61
# 3   4        Stewart Ford   36
# 4   5   Williams Supertec   35
#
#
# Scraping data for 1998...
# Data for 1998 saved to f1_team_standings/f1_team_standings_1998.csv
#   POS                 TEAM  PTS
# 0   1     McLaren Mercedes  156
# 1   2              Ferrari  133
# 2   3  Williams Mecachrome   38
# 3   4   Jordan Mugen Honda   34
# 4   5    Benetton Playlife   33
#
#
# Scraping data for 1997...
# Data for 1997 saved to f1_team_standings/f1_team_standings_1997.csv
#   POS              TEAM  PTS
# 0   1  Williams Renault  123
# 1   2           Ferrari  102
# 2   3  Benetton Renault   67
# 3   4  McLaren Mercedes   63
# 4   5    Jordan Peugeot   33
#
#
# Scraping data for 1996...
# Data for 1996 saved to f1_team_standings/f1_team_standings_1996.csv
#   POS              TEAM  PTS
# 0   1  Williams Renault  175
# 1   2           Ferrari   70
# 2   3  Benetton Renault   68
# 3   4  McLaren Mercedes   49
# 4   5    Jordan Peugeot   22
#
#
# Scraping data for 1995...
# Data for 1995 saved to f1_team_standings/f1_team_standings_1995.csv
#   POS                TEAM  PTS
# 0   1    Benetton Renault  137
# 1   2    Williams Renault  112
# 2   3             Ferrari   73
# 3   4    McLaren Mercedes   30
# 4   5  Ligier Mugen Honda   24
#
#
# Scraping data for 1994...
# Data for 1994 saved to f1_team_standings/f1_team_standings_1994.csv
#   POS              TEAM  PTS
# 0   1  Williams Renault  118
# 1   2     Benetton Ford  103
# 2   3           Ferrari   71
# 3   4   McLaren Peugeot   42
# 4   5       Jordan Hart   28
#
#
# Scraping data for 1993...
# Data for 1993 saved to f1_team_standings/f1_team_standings_1993.csv
#   POS              TEAM  PTS
# 0   1  Williams Renault  168
# 1   2      McLaren Ford   84
# 2   3     Benetton Ford   72
# 3   4           Ferrari   28
# 4   5    Ligier Renault   23
#
#
# Scraping data for 1992...
# Data for 1992 saved to f1_team_standings/f1_team_standings_1992.csv
#   POS              TEAM  PTS
# 0   1  Williams Renault  164
# 1   2     McLaren Honda   99
# 2   3     Benetton Ford   91
# 3   4           Ferrari   21
# 4   5        Lotus Ford   13
#
#
# Scraping data for 1991...
# Data for 1991 saved to f1_team_standings/f1_team_standings_1991.csv
#   POS              TEAM   PTS
# 0   1     McLaren Honda   139
# 1   2  Williams Renault   125
# 2   3           Ferrari  55.5
# 3   4     Benetton Ford  38.5
# 4   5       Jordan Ford    13
#
#
# Scraping data for 1990...
# Data for 1990 saved to f1_team_standings/f1_team_standings_1990.csv
#   POS              TEAM  PTS
# 0   1     McLaren Honda  121
# 1   2           Ferrari  110
# 2   3     Benetton Ford   71
# 3   4  Williams Renault   57
# 4   5      Tyrrell Ford   16
#
#
# Scraping data for 1989...
# Data for 1989 saved to f1_team_standings/f1_team_standings_1989.csv
#   POS              TEAM  PTS
# 0   1     McLaren Honda  141
# 1   2  Williams Renault   77
# 2   3           Ferrari   59
# 3   4     Benetton Ford   39
# 4   5      Tyrrell Ford   16
#
#
# Scraping data for 1988...
# Data for 1988 saved to f1_team_standings/f1_team_standings_1988.csv
#   POS             TEAM  PTS
# 0   1    McLaren Honda  199
# 1   2          Ferrari   65
# 2   3    Benetton Ford   39
# 3   4  Arrows Megatron   23
# 4   5      Lotus Honda   23
#
#
# Scraping data for 1987...
# Data for 1987 saved to f1_team_standings/f1_team_standings_1987.csv
#   POS            TEAM  PTS
# 0   1  Williams Honda  137
# 1   2     McLaren TAG   76
# 2   3     Lotus Honda   64
# 3   4         Ferrari   53
# 4   5   Benetton Ford   28
#
#
# Scraping data for 1986...
# Data for 1986 saved to f1_team_standings/f1_team_standings_1986.csv
#   POS            TEAM  PTS
# 0   1  Williams Honda  141
# 1   2     McLaren TAG   96
# 2   3   Lotus Renault   58
# 3   4         Ferrari   37
# 4   5  Ligier Renault   29
#
#
# Scraping data for 1985...
# Data for 1985 saved to f1_team_standings/f1_team_standings_1985.csv
#   POS            TEAM PTS
# 0   1     McLaren TAG  90
# 1   2         Ferrari  82
# 2   3   Lotus Renault  71
# 3   4  Williams Honda  71
# 4   5     Brabham BMW  26
#
#
# Scraping data for 1984...
# Data for 1984 saved to f1_team_standings/f1_team_standings_1984.csv
#   POS           TEAM    PTS
# 0   1    McLaren TAG  143.5
# 1   2        Ferrari   57.5
# 2   3  Lotus Renault     47
# 3   4    Brabham BMW     38
# 4   5        Renault     34
#
#
# Scraping data for 1983...
# Data for 1983 saved to f1_team_standings/f1_team_standings_1983.csv
#   POS           TEAM PTS
# 0   1        Ferrari  89
# 1   2        Renault  79
# 2   3    Brabham BMW  72
# 3   4  Williams Ford  36
# 4   5   McLaren Ford  34
#
#
# Scraping data for 1982...
# Data for 1982 saved to f1_team_standings/f1_team_standings_1982.csv
#   POS           TEAM PTS
# 0   1        Ferrari  74
# 1   2   McLaren Ford  69
# 2   3        Renault  62
# 3   4  Williams Ford  58
# 4   5     Lotus Ford  30
#
#
# Scraping data for 1981...
# Data for 1981 saved to f1_team_standings/f1_team_standings_1981.csv
#   POS           TEAM PTS
# 0   1  Williams Ford  95
# 1   2   Brabham Ford  61
# 2   3        Renault  54
# 3   4   Ligier Matra  44
# 4   5        Ferrari  34
#
#
# Scraping data for 1980...
# Data for 1980 saved to f1_team_standings/f1_team_standings_1980.csv
#   POS           TEAM  PTS
# 0   1  Williams Ford  120
# 1   2    Ligier Ford   66
# 2   3   Brabham Ford   55
# 3   4        Renault   38
# 4   5     Lotus Ford   14
#
#
# Scraping data for 1979...
# Data for 1979 saved to f1_team_standings/f1_team_standings_1979.csv
#   POS           TEAM  PTS
# 0   1        Ferrari  113
# 1   2  Williams Ford   75
# 2   3    Ligier Ford   61
# 3   4     Lotus Ford   39
# 4   5   Tyrrell Ford   28
#
#
# Scraping data for 1978...
# Data for 1978 saved to f1_team_standings/f1_team_standings_1978.csv
#   POS                TEAM PTS
# 0   1          Lotus Ford  86
# 1   2             Ferrari  58
# 2   3  Brabham Alfa Romeo  53
# 3   4        Tyrrell Ford  38
# 4   5           Wolf Ford  24
#
#
# Scraping data for 1977...
# Data for 1977 saved to f1_team_standings/f1_team_standings_1977.csv
#   POS                TEAM PTS
# 0   1             Ferrari  95
# 1   2          Lotus Ford  62
# 2   3        McLaren Ford  60
# 3   4           Wolf Ford  55
# 4   5  Brabham Alfa Romeo  27
#
#
# Scraping data for 1976...
# Data for 1976 saved to f1_team_standings/f1_team_standings_1976.csv
#   POS          TEAM PTS
# 0   1       Ferrari  83
# 1   2  McLaren Ford  74
# 2   3  Tyrrell Ford  71
# 3   4    Lotus Ford  29
# 4   5   Penske Ford  20
#
#
# Scraping data for 1975...
# Data for 1975 saved to f1_team_standings/f1_team_standings_1975.csv
#   POS          TEAM   PTS
# 0   1       Ferrari  72.5
# 1   2  Brabham Ford    54
# 2   3  McLaren Ford    53
# 3   4  Hesketh Ford    33
# 4   5  Tyrrell Ford    25
#
#
# Scraping data for 1974...
# Data for 1974 saved to f1_team_standings/f1_team_standings_1974.csv
#   POS          TEAM PTS
# 0   1  McLaren Ford  73
# 1   2       Ferrari  65
# 2   3  Tyrrell Ford  52
# 3   4    Lotus Ford  42
# 4   5  Brabham Ford  35
#
#
# Scraping data for 1973...
# Data for 1973 saved to f1_team_standings/f1_team_standings_1973.csv
#   POS          TEAM PTS
# 0   1    Lotus Ford  92
# 1   2  Tyrrell Ford  82
# 2   3  McLaren Ford  58
# 3   4  Brabham Ford  22
# 4   5    March Ford  14
#
#
# Scraping data for 1972...
# Data for 1972 saved to f1_team_standings/f1_team_standings_1972.csv
#   POS          TEAM PTS
# 0   1    Lotus Ford  61
# 1   2  Tyrrell Ford  51
# 2   3  McLaren Ford  47
# 3   4       Ferrari  33
# 4   5  Surtees Ford  18
#
#
# Scraping data for 1971...
# Data for 1971 saved to f1_team_standings/f1_team_standings_1971.csv
#   POS          TEAM PTS
# 0   1  Tyrrell Ford  73
# 1   2           BRM  36
# 2   3       Ferrari  33
# 3   4    March Ford  33
# 4   5    Lotus Ford  21
#
#
# Scraping data for 1970...
# Data for 1970 saved to f1_team_standings/f1_team_standings_1970.csv
#   POS          TEAM PTS
# 0   1    Lotus Ford  59
# 1   2       Ferrari  52
# 2   3    March Ford  48
# 3   4  Brabham Ford  35
# 4   5  McLaren Ford  35
#
#
# Scraping data for 1969...
# Data for 1969 saved to f1_team_standings/f1_team_standings_1969.csv
#   POS          TEAM PTS
# 0   1    Matra Ford  66
# 1   2  Brabham Ford  49
# 2   3    Lotus Ford  47
# 3   4  McLaren Ford  38
# 4   5       Ferrari   7
#
#
# Scraping data for 1968...
# Data for 1968 saved to f1_team_standings/f1_team_standings_1968.csv
#   POS          TEAM PTS
# 0   1    Lotus Ford  62
# 1   2  McLaren Ford  49
# 2   3    Matra Ford  45
# 3   4       Ferrari  32
# 4   5           BRM  28
#
#
# Scraping data for 1967...
# Data for 1967 saved to f1_team_standings/f1_team_standings_1967.csv
#   POS             TEAM PTS
# 0   1    Brabham Repco  63
# 1   2       Lotus Ford  44
# 2   3  Cooper Maserati  28
# 3   4            Honda  20
# 4   5          Ferrari  20
#
#
# Scraping data for 1966...
# Data for 1966 saved to f1_team_standings/f1_team_standings_1966.csv
#   POS             TEAM PTS
# 0   1    Brabham Repco  42
# 1   2          Ferrari  31
# 2   3  Cooper Maserati  30
# 3   4              BRM  22
# 4   5        Lotus BRM  13
#
#
# Scraping data for 1965...
# Data for 1965 saved to f1_team_standings/f1_team_standings_1965.csv
#   POS            TEAM PTS
# 0   1    Lotus Climax  54
# 1   2             BRM  45
# 2   3  Brabham Climax  27
# 3   4         Ferrari  26
# 4   5   Cooper Climax  14
#
#
# Scraping data for 1964...
# Data for 1964 saved to f1_team_standings/f1_team_standings_1964.csv
#   POS            TEAM PTS
# 0   1         Ferrari  45
# 1   2             BRM  42
# 2   3    Lotus Climax  37
# 3   4  Brabham Climax  30
# 4   5   Cooper Climax  16
#
#
# Scraping data for 1963...
# Data for 1963 saved to f1_team_standings/f1_team_standings_1963.csv
#   POS            TEAM PTS
# 0   1    Lotus Climax  54
# 1   2             BRM  36
# 2   3  Brabham Climax  28
# 3   4         Ferrari  26
# 4   5   Cooper Climax  25
#
#
# Scraping data for 1962...
# Data for 1962 saved to f1_team_standings/f1_team_standings_1962.csv
#   POS           TEAM PTS
# 0   1            BRM  42
# 1   2   Lotus Climax  36
# 2   3  Cooper Climax  29
# 3   4    Lola Climax  19
# 4   5        Porsche  18
#
#
# Scraping data for 1961...
# Data for 1961 saved to f1_team_standings/f1_team_standings_1961.csv
#   POS           TEAM PTS
# 0   1        Ferrari  40
# 1   2   Lotus Climax  32
# 2   3        Porsche  22
# 3   4  Cooper Climax  14
# 4   5     BRM Climax   7
#
#
# Scraping data for 1960...
# Data for 1960 saved to f1_team_standings/f1_team_standings_1960.csv
#   POS             TEAM PTS
# 0   1    Cooper Climax  48
# 1   2     Lotus Climax  34
# 2   3          Ferrari  26
# 3   4              BRM   8
# 4   5  Cooper Maserati   3
#
#
# Scraping data for 1959...
# Data for 1959 saved to f1_team_standings/f1_team_standings_1959.csv
#   POS           TEAM PTS
# 0   1  Cooper Climax  40
# 1   2        Ferrari  32
# 2   3            BRM  18
# 3   4   Lotus Climax   5
#
#
# Scraping data for 1958...
# Data for 1958 saved to f1_team_standings/f1_team_standings_1958.csv
#   POS           TEAM PTS
# 0   1        Vanwall  48
# 1   2        Ferrari  40
# 2   3  Cooper Climax  31
# 3   4            BRM  18
# 4   5       Maserati   6
#
#
# Scraping data for 1957...
# No data found for 1957
# No data available for 1957
#
# Scraping data for 1956...
# No data found for 1956
# No data available for 1956
#
# Scraping data for 1955...
# No data found for 1955
# No data available for 1955
#
# Scraping data for 1954...
# No data found for 1954
# No data available for 1954
#
# Scraping data for 1953...
# No data found for 1953
# No data available for 1953
#
# Scraping data for 1952...
# No data found for 1952
# No data available for 1952
#
# Scraping data for 1951...
# No data found for 1951
# No data available for 1951
#
# Scraping data for 1950...
# No data found for 1950
# No data available for 1950
#
# Scraping complete. CSV files have been saved in the 'f1_standings' directory.
